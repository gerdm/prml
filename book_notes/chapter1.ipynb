# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import det

# %%
plt.style.use("seaborn")

# %% [markdown]
# # Chapter 1: Introduction
#
# ## Bayesian Probabilities
# Consider a probability distribution driven by a set of parameters $w$ and observed data $D$. Depending on the point of view about $w$  we might consider knowing the *true* value of $w$ considering $D$ in the following two ways:
#
# * **frequentist POV**: $w$ is unique but unknown, we can estimate how close we are to $w$ via $D$
# * **bayesian POV**: $D$ is unique (the one observed); $w$ is a random variable (might change, we will see its effect once in $D$)
#
# 	In both the frequentist POV and the bayesian POV we make use of MLE $\mathbb{P}(D|w)$ . In ML, the negative log-likelyhood is known as the **error function**
#
# $$
# 	p(w | D) = \frac{p(D|w)p(w)}{p(D)}
# $$
#
# Where,
# * $p(w|D)$ is the uncertainty in $w$ after having observed $D$
# * $p(w)$ is the prior probability distribution; where we capture our prior  beliefs
# * $p(D|w)$ is the likelyhood function. It expresses how probable is the observed data for different values of $w$
#
# ### The Gaussian Distribution
# The gaussian distribution is defined in the following way:
# $$
#     \mathcal{N}(x | \mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{1}{2\sigma^2}(x - \mu)^2}
# $$
#
# An alternative way to represent a gaussian distribution is by considering a *precision* term denoted by $\beta := 1 / \sigma^2$
# $$
#     \mathcal{N}(x | \mu, \beta^{-1}) = \frac{\beta^{1/2}}{\sqrt{2\pi\sigma^2}}e^{-\frac{\beta}{2}(x - \mu)^2}
# $$

# %%
def norm_pdf(x, mu, sigma2): return 1 / np.sqrt(2 * np.pi * sigma2) * np.exp(-(x - mu)**2 / (2 * sigma2))
xrange = np.linspace(-4, 4, 100)
plt.plot(xrange, norm_pdf(xrange, 0, 1), label=r"$\mu=0; \ \sigma^2=1$")
plt.plot(xrange, norm_pdf(xrange, 1, 2), label=r"$\mu=1; \ \sigma^2=2$")
plt.plot(xrange, norm_pdf(xrange, -1, 3), label=r"$\mu=-1; \ \sigma^2=3$")
plt.legend(fontsize=15)

# %% [markdown]
# The gaussian distribution defined over a $D$ dimensional vector $X$ is
#
# $$
#     \mathcal{N}(X | \mu, \Sigma) = \frac{1}{(2\pi)^{D/2}\det(\Sigma)^{1/2}}\exp\left(-\frac{1}{2}(x - \mu)^T\Sigma(x - \mu)\right)
# $$

# %%
sigma = np.eye(2)
def norm_pdf_v(X, mu, sigma):
    D = len(X)
    den = (2 * np.pi) ** (D / 2) * det(sigma) ** (1/2)
    num = np.exp(-(X - mu).T @ sigma @ (X - mu) / 2)
    return num / den

# %%
Xrange - mu0.reshape(2, 1, 1)

# %%
Xrange.shape
# Out:
# (2, 60, 60)

# %%
xt = np.array([1, 3]).reshape(2, 1)
(xt - mu0).shape
# Out:
# (2, 1)

# %%
Xrange.shape
# Out:
# (2, 60, 60)

# %%
sigma.shape
# Out:
# (2, 2)

# %%
((Xrange - mu0.reshape(2, 1, 1)).T @ sigma) @ Xrange
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-e94c690c4fd2> in <module>
# ----> 1 ((Xrange - mu0.reshape(2, 1, 1)).T @ sigma) @ Xrange
#
# ValueError: shapes (60,60,2) and (2,60,60) not aligned: 2 (dim 2) != 60 (dim 1)

# %%
Xrange = np.mgrid[-3:3:0.1, -3:3:0.1]
plt.contourf(*Xrange, Xrange[0])

# %%
Xrange[0].shape
# Out:
# (60, 60)

# %%
mu0 = np.array([[0, 0]]).T
norm_pdf_v(Xrange, mu0, sigma)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-1b8889681714> in <module>
#       1 mu0 = np.array([[0, 0]]).T
# ----> 2 norm_pdf_v(Xrange, mu0, sigma)
#
# <ipython-input-68-daaa309eaad9> in norm_pdf_v(X, mu, sigma)
#       3     D = len(X)
#       4     den = (2 * np.pi) ** (D / 2) * det(sigma) ** (1/2)
# ----> 5     num = np.exp(-(X - mu).T @ sigma @ (X - mu) / 2)
#       6     return num / den
#
# ValueError: operands could not be broadcast together with shapes (2,60,60) (2,1)

# %%
mu0.reshape(1, 1, 2).shape
# Out:
# (1, 1, 2)

# %%
plt.contourf(Xrange(Xrange - mu0.reshape(2, 1, 1)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-a5c40be45aa6> in <module>
# ----> 1 plt.contourf((Xrange - mu0.reshape(2, 1, 1)))
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2547     __ret = gca().contourf(
#    2548         *args, **({"data": data} if data is not None else {}),
# -> 2549         **kwargs)
#    2550     if __ret._A is not None: sci(__ret)  # noqa
#    2551     return __ret
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6226     def contourf(self, *args, **kwargs):
#    6227         kwargs['filled'] = True
# -> 6228         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6229         self.autoscale_view()
#    6230         return contours
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1491                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1492
# -> 1493             x, y, z = self._contour_args(args, kwargs)
#    1494
#    1495             _mask = ma.getmask(z)
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1546         if Nargs <= 2:
#    1547             z = ma.asarray(args[0], dtype=np.float64)
# -> 1548             x, y = self._initialize_x_y(z)
#    1549             args = args[1:]
#    1550         elif Nargs <= 4:
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/contour.py in _initialize_x_y(self, z)
#    1633         """
#    1634         if z.ndim != 2:
# -> 1635             raise TypeError("Input must be a 2D array.")
#    1636         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1637             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input must be a 2D array.

# %%
mu0.shape
# Out:
# (2, 1)

# %%
sigma.shape
# Out:
# (2, 2)

# %%
(mu0 - mu0).T @ sigma @ (mu0 - mu0)
# Out:
# array([[0.]])
